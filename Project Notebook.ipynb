# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
#  ## MOHINI RAHATE

# %% [markdown]
# ### _Student_

# %% [markdown]
# # 1. Simple Python Code.

# %%
s = "hello"
print(s.capitalize())  
print(s.upper())       
print(s.rjust(7))      
print(s.center(7))     
print(s.replace('l', '(ell)'))
# Out:
# Hello
# HELLO
#   hello
#  hello
# he(ell)(ell)o

# %% [markdown]
# # 2. Green Text

# %% [markdown]
# ## <font color=green>The Text to be show in Green</font>

# %% [markdown]
# # 3. Numbered List

# %% [markdown]
# 1. One
# 2. Two
# 3. Three

# %% [markdown]
# # 4. Table

# %% [markdown]
# <table style="width:50%">
#   <tr>
#     <th>Firstname</th>
#     <th>Lastname</th>
#   </tr>
#   <tr>
#     <td>Mohini</td>
#     <td>Rahate</td>
#   </tr>
#     <tr>
#     <td>Mohini</td>
#     <td>Rahate</td>
#   </tr>
#     <tr>
#     <td>Mohini</td>
#     <td>Rahate</td>
#   </tr>
# </table>

# %% [markdown]
# # 5. Hyperlink

# %% [markdown]
# [click me](http://google.com)

# %% [markdown]
# # 6. Image

# %% [markdown]
# <img src="https://miro.medium.com/max/1400/1*3Fm1Va6Py9GIcNXIMeqp_g.png" width ="500" height=500>

# %% [markdown]
# # 7. Blocked Quotes

# %% [markdown]
# <blockquote>Happiness can be found, even in darkest of time, if one only remeber to turn on the light - Albus Dumbledore</blockquote>

# %% [markdown]
# # 8. Embedding Webpage

# %%
import IPython
url = 'https://www.who.int/emergencies/diseases/novel-coronavirus-2019'
iframe = '<iframe src=' + url + ' width=700 height=350></iframe>'
IPython.display.HTML(iframe)
# Out:
# <iframe src=https://www.who.int/emergencies/diseases/novel-coronavirus-2019 width=700 height=350></iframe>

# %% [markdown]
# # 9. Embedding Youtube Video

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('gHjdie-4wmU', width = 800, height = 500)
